# %% [markdown]
# ### Testing whether web scraping works with Kareem to capture per game stats

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
import re
import numpy as np

# %%
player_list = os.listdir("threadedPlayers/a")
player_0 = player_list[2]

# %%
player_0
# Out:
# 'Hassan Adams.html'

# %%
with open("threadedPlayers/a/{}".format(player_0)) as f:
    page = f.read()

# %%
soup = BeautifulSoup(page, "lxml")

# %%
player_pergame = soup.find('table', {'id':'per_game'})

# %%
player_pergame_table = pd.read_html(str(player_pergame))[0]

# %%
player_pergame_table
# Out:
#      Season   Age                                     Tm  \
# 0   2006-07  22.0                                    NJN
# 1   2007-08  23.0  Did Not Play (other pro league—Italy)
# 2   2008-09  24.0                                    TOR
# 3    Career   NaN                                    NaN
# 4       NaN   NaN                                    NaN
# 5  1 season   NaN                                    NJN
# 6  1 season   NaN                                    TOR
#
#                                       Lg  \
# 0                                    NBA
# 1  Did Not Play (other pro league—Italy)
# 2                                    NBA
# 3                                    NBA
# 4                                    NaN
# 5                                    NBA
# 6                                    NBA
#
#                                      Pos  \
# 0                                     SG
# 1  Did Not Play (other pro league—Italy)
# 2                                     SG
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
#
#                                        G  \
# 0                                     61
# 1  Did Not Play (other pro league—Italy)
# 2                                     12
# 3                                     73
# 4                                    NaN
# 5                                     61
# 6                                     12
#
#                                       GS  \
# 0                                      8
# 1  Did Not Play (other pro league—Italy)
# 2                                      0
# 3                                      8
# 4                                    NaN
# 5                                      8
# 6                                      0
#
#                                       MP  \
# 0                                    8.1
# 1  Did Not Play (other pro league—Italy)
# 2                                    4.3
# 3                                    7.5
# 4                                    NaN
# 5                                    8.1
# 6                                    4.3
#
#                                       FG  \
# 0                                    1.2
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.3
# 3                                    1.1
# 4                                    NaN
# 5                                    1.2
# 6                                    0.3
#
#                                      FGA  ...  \
# 0                                    2.2  ...
# 1  Did Not Play (other pro league—Italy)  ...
# 2                                    1.1  ...
# 3                                    2.0  ...
# 4                                    NaN  ...
# 5                                    2.2  ...
# 6                                    1.1  ...
#
#                                      FT%  \
# 0                                   .667
# 1  Did Not Play (other pro league—Italy)
# 2                                   .500
# 3                                   .643
# 4                                    NaN
# 5                                   .667
# 6                                   .500
#
#                                      ORB  \
# 0                                    0.6
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.1
# 3                                    0.5
# 4                                    NaN
# 5                                    0.6
# 6                                    0.1
#
#                                      DRB  \
# 0                                    0.7
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.5
# 3                                    0.7
# 4                                    NaN
# 5                                    0.7
# 6                                    0.5
#
#                                      TRB  \
# 0                                    1.3
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.6
# 3                                    1.2
# 4                                    NaN
# 5                                    1.3
# 6                                    0.6
#
#                                      AST  \
# 0                                    0.2
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.1
# 3                                    0.2
# 4                                    NaN
# 5                                    0.2
# 6                                    0.1
#
#                                      STL  \
# 0                                    0.3
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.1
# 3                                    0.2
# 4                                    NaN
# 5                                    0.3
# 6                                    0.1
#
#                                      BLK  \
# 0                                    0.1
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.1
# 3                                    0.1
# 4                                    NaN
# 5                                    0.1
# 6                                    0.1
#
#                                      TOV  \
# 0                                    0.4
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.3
# 3                                    0.4
# 4                                    NaN
# 5                                    0.4
# 6                                    0.3
#
#                                       PF  \
# 0                                    0.8
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.3
# 3                                    0.7
# 4                                    NaN
# 5                                    0.8
# 6                                    0.3
#
#                                      PTS
# 0                                    2.9
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.9
# 3                                    2.5
# 4                                    NaN
# 5                                    2.9
# 6                                    0.9
#
# [7 rows x 30 columns]

# %%
career_row = player_pergame_table[player_pergame_table['Season'] == 'Career'].index.tolist()[0]
player_pergame_table_processed = player_pergame_table.iloc[:career_row]

# %%
player_pergame_table_processed
# Out:
#     Season   Age                                     Tm  \
# 0  2006-07  22.0                                    NJN
# 1  2007-08  23.0  Did Not Play (other pro league—Italy)
# 2  2008-09  24.0                                    TOR
#
#                                       Lg  \
# 0                                    NBA
# 1  Did Not Play (other pro league—Italy)
# 2                                    NBA
#
#                                      Pos  \
# 0                                     SG
# 1  Did Not Play (other pro league—Italy)
# 2                                     SG
#
#                                        G  \
# 0                                     61
# 1  Did Not Play (other pro league—Italy)
# 2                                     12
#
#                                       GS  \
# 0                                      8
# 1  Did Not Play (other pro league—Italy)
# 2                                      0
#
#                                       MP  \
# 0                                    8.1
# 1  Did Not Play (other pro league—Italy)
# 2                                    4.3
#
#                                       FG  \
# 0                                    1.2
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.3
#
#                                      FGA  ...  \
# 0                                    2.2  ...
# 1  Did Not Play (other pro league—Italy)  ...
# 2                                    1.1  ...
#
#                                      FT%  \
# 0                                   .667
# 1  Did Not Play (other pro league—Italy)
# 2                                   .500
#
#                                      ORB  \
# 0                                    0.6
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.1
#
#                                      DRB  \
# 0                                    0.7
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.5
#
#                                      TRB  \
# 0                                    1.3
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.6
#
#                                      AST  \
# 0                                    0.2
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.1
#
#                                      STL  \
# 0                                    0.3
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.1
#
#                                      BLK  \
# 0                                    0.1
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.1
#
#                                      TOV  \
# 0                                    0.4
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.3
#
#                                       PF  \
# 0                                    0.8
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.3
#
#                                      PTS
# 0                                    2.9
# 1  Did Not Play (other pro league—Italy)
# 2                                    0.9
#
# [3 rows x 30 columns]

# %%
player_teams = player_pergame_table['Tm'].unique()
player_teams
# Out:
# array(['NJN', 'Did Not Play\xa0(other pro league—Italy)', 'TOR', nan],
#       dtype=object)

# %%
player_teams = player_teams[~pd.isnull(player_teams)]
# Convert the ndarray to a list of strings
player_teams_list = player_teams.astype(str).tolist()

# Remove instances longer than 4 letters
player_teams_list = [team for team in player_teams_list if len(team) <= 4]

# Convert the list back to a NumPy ndarray
player_teams = np.array(player_teams_list, dtype=object)
player_teams
# Out:
# array(['NJN', 'TOR'], dtype=object)

# %%
# Calculate the maximum numerical values for columns 4 onwards
max_numerical_values = player_pergame_table_processed.iloc[:, 5:].apply(pd.to_numeric, errors='coerce').max()

# Create a DataFrame with the maximum values as a single row
max_values_df = max_numerical_values.to_frame().T

# Update the first row of the DataFrame to keep the original values for columns 0 to 3
player_full = pd.concat([player_pergame_table_processed.iloc[:1, :5], max_values_df], axis=1)

player_full
# Out:
#     Season   Age   Tm   Lg Pos     G   GS   MP   FG  FGA  ...    FT%  ORB  \
# 0  2006-07  22.0  NJN  NBA  SG  61.0  8.0  8.1  1.2  2.2  ...  0.667  0.6
#
#    DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# 0  0.7  1.3  0.2  0.3  0.1  0.4  0.8  2.9
#
# [1 rows x 30 columns]

# %%
player_full.at[0, 'Tm'] = np.array(player_teams_list, dtype=object)
player_full
# Out:
#     Season   Age          Tm   Lg Pos     G   GS   MP   FG  FGA  ...    FT%  \
# 0  2006-07  22.0  [NJN, TOR]  NBA  SG  61.0  8.0  8.1  1.2  2.2  ...  0.667
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# 0  0.6  0.7  1.3  0.2  0.3  0.1  0.4  0.8  2.9
#
# [1 rows x 30 columns]

# %% [markdown]
# ## Got a processed per game row with max of each category kept and "Tm" being an array of all teams played on

# %% [markdown]
# ### Now to try game highs section

# %%
player_highs = soup.find('table', {'id':'stathead_insights'})

# %%
player_highs_table = pd.read_html(str(player_highs))[0]
player_highs_table
# Out:
#                  Highlight  Unnamed: 1                        In Stathead
# 0      Career high, Points        16.0  View full stats from top 20 games
# 1    Career high, Rebounds         8.0  View full stats from top 20 games
# 2     Career high, Assists         3.0  View full stats from top 20 games
# 3      Career high, Steals         3.0  View full stats from top 20 games
# 4      Career high, Blocks         1.0  View full stats from top 20 games
# 5  Career high, Game Score        13.5  View full stats from top 20 games

# %%
player_highs_table['Unnamed: 1'].tolist()
# Out:
# [16.0, 8.0, 3.0, 3.0, 1.0, 13.5]

# %%
player_highs_table["Highlight"].tolist()
# Out:
# ['Career high, Points',
#  'Career high, Rebounds',
#  'Career high, Assists',
#  'Career high, Steals',
#  'Career high, Blocks',
#  'Career high, Game Score']

# %%
player_full[player_highs_table["Highlight"].tolist()] = player_highs_table['Unnamed: 1'].tolist()

# %%
player_full
# Out:
#     Season   Age          Tm   Lg Pos     G   GS   MP   FG  FGA  ...  BLK  \
# 0  2006-07  22.0  [NJN, TOR]  NBA  SG  61.0  8.0  8.1  1.2  2.2  ...  0.1
#
#    TOV   PF  PTS  Career high, Points  Career high, Rebounds  \
# 0  0.4  0.8  2.9                 16.0                    8.0
#
#    Career high, Assists  Career high, Steals  Career high, Blocks  \
# 0                   3.0                  3.0                  1.0
#
#    Career high, Game Score
# 0                     13.5
#
# [1 rows x 36 columns]

# %% [markdown]
# ### Now college stats

# %%
player_college = soup.find('table', {'id':'all_college_stats'})

# %%
player_college_table = pd.read_html(str(player_college))[0]

# %%
player_college_table.columns = player_college_table.columns.droplevel()
player_college_table
# Out:
#     Season   Age  College    G    MP   FG   FGA  3P  3PA   FT  ...  TOV   PF  \
# 0  2002-03  18.0  ARIZONA   32   572  118   241   7   34   48  ...   42   48
# 1  2003-04  19.0  ARIZONA   30   915  200   369  38   99   77  ...   58   79
# 2  2004-05  20.0  ARIZONA   37  1091  198   403  13   43   60  ...   86   76
# 3  2005-06  21.0  ARIZONA   31  1031  234   490  17   65   58  ...   69   60
# 4   Career   NaN      NaN  130  3609  750  1503  75  241  243  ...  255  263
#
#     PTS    FG%    3P%    FT%    MP   PTS  TRB  AST
# 0   291  0.490  0.206  0.787  17.9   9.1  3.4  0.6
# 1   515  0.542  0.384  0.733  30.5  17.2  7.3  1.6
# 2   469  0.491  0.302  0.714  29.5  12.7  6.0  2.8
# 3   543  0.478  0.262  0.611  33.3  17.5  5.0  2.9
# 4  1818  0.499  0.311  0.704  27.8  14.0  5.4  2.0
#
# [5 rows x 26 columns]

# %%
player_college_teams = player_college_table['College'].unique()
player_college_teams = player_college_teams[~pd.isnull(player_college_teams)]
player_college_teams
# Out:
# array(['ARIZONA'], dtype=object)

# %%
player_full.at[0, 'College'] = player_college_teams

# %%
player_full
# Out:
#     Season   Age          Tm   Lg Pos     G   GS   MP   FG  FGA  ...  TOV  \
# 0  2006-07  22.0  [NJN, TOR]  NBA  SG  61.0  8.0  8.1  1.2  2.2  ...  0.4
#
#     PF  PTS  Career high, Points  Career high, Rebounds  Career high, Assists  \
# 0  0.8  2.9                 16.0                    8.0                   3.0
#
#    Career high, Steals  Career high, Blocks  Career high, Game Score  \
# 0                  3.0                  1.0                     13.5
#
#      College
# 0  [ARIZONA]
#
# [1 rows x 37 columns]

# %% [markdown]
# ### Now get all the awards

# %%
player_allstar = soup.find(id='leaderboard_allstar')

# %%
if player_allstar is not None:
    player_all_star_text = [button.text for button in player_allstar][-2]
    player_num_all_stars = int(re.findall("\d+", player_all_star_text)[0])
    player_full["All Star Games"] = player_num_all_stars
else:
    player_full["All Star Games"] = 0

# %%
player_champs = soup.find(id='leaderboard_championships')

# %%
if player_champs is not None:
    player_champs_text = [button.text for button in player_allstar][-2]
    player_num_champs = int(re.findall("\d+", player_all_star_text)[0])
    player_full["Championships"] = player_num_all_stars
else:
    player_full["Championships"] = 0

# %%
player_hof = soup.find(id='leaderboard_hof_prob')

# %%
if player_hof is not None:
    player_hof_text = [button.text for button in player_hof][-2]
    player_hof_prob = int(re.findall("\d+", player_hof_text)[0])
    if (player_hof_prob) == 100:
        player_full["HOF"] = 1
    else:
        player_full["HOF"] = 0
else:
    player_full["HOF"] = 0

# %%
player_full
# Out:
#     Season   Age          Tm   Lg Pos     G   GS   MP   FG  FGA  ...  \
# 0  2006-07  22.0  [NJN, TOR]  NBA  SG  61.0  8.0  8.1  1.2  2.2  ...
#
#    Career high, Points  Career high, Rebounds  Career high, Assists  \
# 0                 16.0                    8.0                   3.0
#
#    Career high, Steals  Career high, Blocks  Career high, Game Score  \
# 0                  3.0                  1.0                     13.5
#
#      College  All Star Games  Championships  HOF
# 0  [ARIZONA]               0              0    0
#
# [1 rows x 40 columns]

# %%
player_drafted = soup.find(id="meta")
player_drafted_p = player_drafted.findAll('p')
desired_p_tag = None
for tag in player_drafted_p:
    if tag.name == 'p' and tag.strong and tag.strong.text.strip() == 'Draft:':
        desired_p_tag = tag
        break

# %%
if desired_p_tag is not None:
    player_draft_text = desired_p_tag.text.split('\n')[-2]
    player_match = re.search(r'\b\d+(?:st|nd|rd|th) pick\b', player_draft_text).group(0)
    player_pick = int(re.findall("\d+", player_match)[0])
    player_full["Pick #"] = player_pick
    player_draft_match = re.search(r'\d{4}\sNBA\sDraft', player_draft_text).group(0)
    player_draft_year = int(re.findall("\d+", player_draft_match)[0])
    player_full["Draft Year"] = player_draft_year
else:
    player_full["Pick #"] = None
    player_full["Draft Year"] = None

# %% [markdown]
# ## Last thing is his image URL

# %%
player_image = soup.find(class_="media-item")

# %%
if player_image is not None:
    player_image_url = player_image.find('img')['src']
else:
    player_image_url = None

# %%
player_full['Image URL'] = player_image_url

# %%
player_full
# Out:
#     Season   Age          Tm   Lg Pos     G   GS   MP   FG  FGA  ...  \
# 0  2006-07  22.0  [NJN, TOR]  NBA  SG  61.0  8.0  8.1  1.2  2.2  ...
#
#    Career high, Steals  Career high, Blocks  Career high, Game Score  \
# 0                  3.0                  1.0                     13.5
#
#      College  All Star Games  Championships  HOF  Pick #  Draft Year  \
# 0  [ARIZONA]               0              0    0      24        2006
#
#    Image URL
# 0       None
#
# [1 rows x 43 columns]

# %% [markdown]
# ### Now try to put all the above code in a for loop

# %%
player_entries = []
player_list = os.listdir("threadedPlayers/a")
for player in player_list:
    with open("threadedPlayers/a/{}".format(player)) as f:
        page = f.read()
    soup = BeautifulSoup(page, "lxml")
    
    # PER GAME
    player_pergame = soup.find('table', {'id':'per_game'})
    player_pergame_table = pd.read_html(str(player_pergame))[0]
    career_row = player_pergame_table[player_pergame_table['Season'] == 'Career'].index.tolist()[0]
    player_pergame_table_processed = player_pergame_table.iloc[:career_row]
    player_teams = player_pergame_table['Tm'].unique()
    
    player_teams = player_teams[~pd.isnull(player_teams)]
    # Convert the ndarray to a list of strings
    player_teams_list = player_teams.astype(str).tolist()

    # Remove instances longer than 4 letters
    player_teams_list = [team for team in player_teams_list if len(team) <= 4]

    # Convert the list back to a NumPy ndarray
    player_teams = np.array(player_teams_list, dtype=object)
    
    # Calculate the maximum numerical values for columns 4 onwards
    max_numerical_values = player_pergame_table_processed.iloc[:, 5:].apply(pd.to_numeric, errors='coerce').max()

    # Create a DataFrame with the maximum values as a single row
    max_values_df = max_numerical_values.to_frame().T

    # Update the first row of the DataFrame to keep the original values for columns 0 to 3
    player_full = pd.concat([player_pergame_table_processed.iloc[:1, :5], max_values_df], axis=1)
    
    # Place teams played on as array
    player_full.at[0, 'Tm'] = player_teams
